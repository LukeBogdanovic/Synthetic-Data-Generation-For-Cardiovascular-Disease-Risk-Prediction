# %%
import sys
PROJECT_ROOT = r"C:\\Dev\\Synthetic-Data-Generation-For-Cardiovascular-Disease-Risk-Prediction\\"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import torch
from classifier import Classifier
# %matplotlib inline
plt.rcParams.update({"font.size":16})
# Out:
# c:\Dev\Synthetic-Data-Generation-For-Cardiovascular-Disease-Risk-Prediction\.venv\Lib\site-packages\torch\cuda\__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
class_names = ['None', 'MI', 'Stroke', 'Syncope']
classifier_metrics = torch.load("models/classifier11/checkpoint.pth", weights_only=False)
class_history = classifier_metrics['history']
class_synth_metrics = classifier_metrics['synth_test']
class_real_metrics = classifier_metrics['real_test']

# %%
class_synth_metrics
# Out:
# {'acc_macro': tensor(0.8972),
#  'acc_micro': tensor(0.9050),
#  'acc_weighted': tensor(0.9050),
#  'conf_mat': tensor([[149,  58,   3,  15],
#          [ 12, 246,   1,   3],
#          [  0,   0, 274,   0],
#          [  1,   2,   0, 236]]),
#  'f1_macro': tensor(0.8966),
#  'f1_micro': tensor(0.9050),
#  'f1_per_class': tensor([0.7700, 0.8662, 0.9928, 0.9574]),
#  'f1_weighted': tensor(0.9010),
#  'precision_macro': tensor(0.9096),
#  'precision_micro': tensor(0.9050),
#  'precision_per_class': tensor([0.9198, 0.8039, 0.9856, 0.9291]),
#  'precision_weighted': tensor(0.9010),
#  'recall_macro': tensor(0.8972),
#  'recall_micro': tensor(0.9050),
#  'recall_per_class': tensor([0.6622, 0.9389, 1.0000, 0.9874]),
#  'recall_weighted': tensor(0.9010),
#  'loss': tensor(0.2459)}

# %%
class_real_metrics
# Out:
# {'acc_macro': tensor(0.9132),
#  'acc_micro': tensor(0.7681),
#  'acc_weighted': tensor(0.7681),
#  'conf_mat': tensor([[90, 25,  3,  3],
#          [ 1, 10,  0,  0],
#          [ 0,  0,  3,  0],
#          [ 0,  0,  0,  3]]),
#  'f1_macro': tensor(0.6543),
#  'f1_micro': tensor(0.7681),
#  'f1_per_class': tensor([0.8491, 0.4348, 0.6667, 0.6667]),
#  'f1_weighted': tensor(0.8081),
#  'precision_macro': tensor(0.5687),
#  'precision_micro': tensor(0.7681),
#  'precision_per_class': tensor([0.9890, 0.2857, 0.5000, 0.5000]),
#  'precision_weighted': tensor(0.8081),
#  'recall_macro': tensor(0.9132),
#  'recall_micro': tensor(0.7681),
#  'recall_per_class': tensor([0.7438, 0.9091, 1.0000, 1.0000]),
#  'recall_weighted': tensor(0.8081),
#  'loss': tensor(0.4635)}

# %%
class_names = ['None', 'MI', 'Stroke', 'Syncope']
classifier_metrics = torch.load("models/classifier12/checkpoint.pth", weights_only=False)
class_history = classifier_metrics['history']
class_synth_metrics = classifier_metrics['synth_test']
class_real_metrics = classifier_metrics['real_test']

# %%
class_synth_metrics
# Out:
# {'acc_macro': tensor(0.9067),
#  'acc_micro': tensor(0.9040),
#  'acc_weighted': tensor(0.9040),
#  'conf_mat': tensor([[189,  68,   2,   7],
#          [ 10, 205,   1,   6],
#          [  2,   0, 285,   0],
#          [  0,   0,   0, 225]]),
#  'f1_macro': tensor(0.9002),
#  'f1_micro': tensor(0.9040),
#  'f1_per_class': tensor([0.8094, 0.8283, 0.9913, 0.9719]),
#  'f1_weighted': tensor(0.9024),
#  'precision_macro': tensor(0.9065),
#  'precision_micro': tensor(0.9040),
#  'precision_per_class': tensor([0.9403, 0.7509, 0.9896, 0.9454]),
#  'precision_weighted': tensor(0.9024),
#  'recall_macro': tensor(0.9067),
#  'recall_micro': tensor(0.9040),
#  'recall_per_class': tensor([0.7105, 0.9234, 0.9930, 1.0000]),
#  'recall_weighted': tensor(0.9024),
#  'loss': tensor(0.2115)}

# %%
class_real_metrics
# Out:
# {'acc_macro': tensor(0.6288),
#  'acc_micro': tensor(0.5580),
#  'acc_weighted': tensor(0.5580),
#  'conf_mat': tensor([[66, 41,  1, 13],
#          [ 0,  7,  0,  4],
#          [ 1,  0,  1,  1],
#          [ 0,  0,  0,  3]]),
#  'f1_macro': tensor(0.3974),
#  'f1_micro': tensor(0.5580),
#  'f1_per_class': tensor([0.7021, 0.2373, 0.4000, 0.2500]),
#  'f1_weighted': tensor(0.6487),
#  'precision_macro': tensor(0.4434),
#  'precision_micro': tensor(0.5580),
#  'precision_per_class': tensor([0.9851, 0.1458, 0.5000, 0.1429]),
#  'precision_weighted': tensor(0.6487),
#  'recall_macro': tensor(0.6288),
#  'recall_micro': tensor(0.5580),
#  'recall_per_class': tensor([0.5455, 0.6364, 0.3333, 1.0000]),
#  'recall_weighted': tensor(0.6487),
#  'loss': tensor(1.3327)}
