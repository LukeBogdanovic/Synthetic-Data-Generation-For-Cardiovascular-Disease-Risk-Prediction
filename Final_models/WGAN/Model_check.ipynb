# %%
import torch
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams.update({"font.size":16})
# Out:
# c:\Dev\college\PhD\Synthetic-Data-Generation-For-Cardiovascular-Disease-Risk-Prediction\.venv\Lib\site-packages\torch\cuda\__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %% [markdown]
# ## Models withour MVDTW Term Augmenting Loss

# %% [markdown]
# ### BiLSTM-CNN Model W/O MVDTW Term Augmenting Loss

# %%
model = torch.load("models/BiLSTM_CNN_WGAN/Model_0_GP_10.0_DTW_0.0/Model.pth", weights_only=False)
metrics_history_1 = model['metrics_history']
print(f"MMD: {metrics_history_1['mmd'][-1]:.4f}")
print(f"MVDTW: {metrics_history_1['mvdtw'][-1]:.4f}")
print(f"W-Gap: {metrics_history_1['wgap'][-1]:.4f}")
# Out:
# MMD: 0.1166
# MVDTW: 0.3278
# W-Gap: 0.5070

# %%
plt.plot(metrics_history_1['epoch'], metrics_history_1['mmd'])
plt.xlabel('Epoch')
plt.ylabel('MMD')
plt.title('MMD Change over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_1['epoch'], metrics_history_1['mvdtw'])
plt.xlabel('Epoch')
plt.ylabel('MVDTW')
plt.title('MVDTW Change over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_1['epoch'], metrics_history_1['wgap'])
plt.xlabel('Epoch')
plt.ylabel('Wasserstein Gap')
plt.title('W-Gap Change over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_1['epoch'], metrics_history_1['critic_loss'], label='Critic Loss')
plt.plot(metrics_history_1['epoch'], metrics_history_1['gen_loss'], label='Gen Loss')
plt.xlabel('Epoch')
plt.ylabel('Wasserstein Loss Score')
plt.title('Loss Changes over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Upsample & CNN Model W/O MVDTW Loss Term

# %%
model = torch.load("models/UpsampleAndCNN_WGAN/Model_0_GP_10.0_DTW_0.0/Model.pth", weights_only=False)
metrics_history_2 = model['metrics_history']
print(f"MMD: {metrics_history_2['mmd'][-1]:.4f}")
print(f"MVDTW: {metrics_history_2['mvdtw'][-1]:.4f}")
print(f"W-Gap: {metrics_history_2['wgap'][-1]:.4f}")
# Out:
# MMD: 0.0904
# MVDTW: 0.3296
# W-Gap: 0.6029

# %%
plt.plot(metrics_history_2['epoch'], metrics_history_2['mmd'])
plt.xlabel('Epoch')
plt.ylabel('MMD')
plt.title('MMD Change over Training Epochs for Upsample-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_2['epoch'], metrics_history_2['mvdtw'])
plt.xlabel('Epoch')
plt.ylabel('MVDTW')
plt.title('MVDTW Change over Training Epochs for Upsample-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_2['epoch'], metrics_history_2['wgap'])
plt.xlabel('Epoch')
plt.ylabel('W-GAP')
plt.title('W-GAP Change over Training Epochs for Upsample-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_2['epoch'], metrics_history_2['critic_loss'], label='Critic Loss')
plt.plot(metrics_history_2['epoch'], metrics_history_2['gen_loss'], label='Gen Loss')
plt.xlabel('Epoch')
plt.ylabel('Wasserstein Loss')
plt.title('Loss Changes over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Transposed 1D Convolution Model W/O MVDTW Loss Term

# %%
model = torch.load("models/DCNN_WGAN/Model_0_GP_10.0_DTW_0.0/Model.pth", weights_only=False)
metrics_history_3 = model['metrics_history']
print(f"MMD: {metrics_history_3['mmd'][-1]:.4f}")
print(f"MVDTW: {metrics_history_3['mvdtw'][-1]:.4f}")
print(f"W-Gap: {metrics_history_3['wgap'][-1]:.4f}")
# Out:
# MMD: 0.3015
# MVDTW: 0.3287
# W-Gap: 0.7863

# %%
plt.plot(metrics_history_3['epoch'], metrics_history_3['mmd'])
plt.xlabel('Epoch')
plt.ylabel('MMD')
plt.title('MMD Change over Training Epochs for Transposed-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_3['epoch'], metrics_history_3['mvdtw'])
plt.xlabel('Epoch')
plt.ylabel('MVDTW')
plt.title('MVDTW Change over Training Epochs for Transposed-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_3['epoch'], metrics_history_3['wgap'])
plt.xlabel('Epoch')
plt.ylabel('W-GAP')
plt.title('W-GAP Change over Training Epochs for Transposed-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_3['epoch'], metrics_history_3['critic_loss'], label='Critic Loss')
plt.plot(metrics_history_3['epoch'], metrics_history_3['gen_loss'], label='Gen Loss')
plt.xlabel('Epoch')
plt.ylabel('Wasserstein Loss Score')
plt.title('Loss Changes over Training Epochs for Transposed-CNN w/o MVDTW Loss Term')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Models with MVDTW Term Augmenting Loss

# %% [markdown]
# ### BiLSTM-CNN Model W/O MVDTW Term Augmenting Loss

# %%
model = torch.load("models/BiLSTM_CNN_WGAN/Model_0_GP_10.0_DTW_1.0/Model.pth", weights_only=False)
metrics_history_1_dtw = model['metrics_history']
print(f"MMD: {metrics_history_1_dtw['mmd'][-1]:.4f}")
print(f"MVDTW: {metrics_history_1_dtw['mvdtw'][-1]:.4f}")
print(f"W-Gap: {metrics_history_1_dtw['wgap'][-1]:.4f}")
# Out:
# MMD: 0.1559
# MVDTW: 0.2401
# W-Gap: 0.5306

# %%
plt.plot(metrics_history_1_dtw['epoch'], metrics_history_1_dtw['mmd'])
plt.xlabel('Epoch')
plt.ylabel('MMD')
plt.title('MMD Change over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_1_dtw['epoch'], metrics_history_1_dtw['mvdtw'])
plt.xlabel('Epoch')
plt.ylabel('MVDTW')
plt.title('MVDTW Change over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_1_dtw['epoch'], metrics_history_1_dtw['wgap'])
plt.xlabel('Epoch')
plt.ylabel('W-GAP')
plt.title('W-GAP Change over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_1_dtw['epoch'], metrics_history_1_dtw['critic_loss'], label='Critic Loss')
plt.plot(metrics_history_1_dtw['epoch'], metrics_history_1_dtw['gen_loss'], label='Gen Loss')
plt.xlabel('Epoch')
plt.ylabel('Wasserstein Loss')
plt.title('Loss Changes over Training Epochs for BiLSTM-CNN w/o MVDTW Loss Term')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Upsample & CNN Model W/O MVDTW Loss Term

# %%
model = torch.load("models/UpsampleAndCNN_WGAN/Model_0_GP_10.0_DTW_1.0/Model.pth", weights_only=False)
metrics_history_2_dtw = model['metrics_history']
print(f"MMD: {metrics_history_2_dtw['mmd'][-1]:.4f}")
print(f"MVDTW: {metrics_history_2_dtw['mvdtw'][-1]:.4f}")
print(f"W-Gap: {metrics_history_2_dtw['wgap'][-1]:.4f}")
# Out:
# MMD: 0.0820
# MVDTW: 0.2463
# W-Gap: 0.6057

# %%
plt.plot(metrics_history_2_dtw['epoch'], metrics_history_2_dtw['mmd'])
plt.xlabel('Epoch')
plt.ylabel('MMD')
plt.title('MMD Change over Training Epochs for Upsample-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_2_dtw['epoch'], metrics_history_2_dtw['mvdtw'])
plt.xlabel('Epoch')
plt.ylabel('MVDTW')
plt.title('MVDTW Change over Training Epochs for Upsample-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_2_dtw['epoch'], metrics_history_2_dtw['wgap'])
plt.xlabel('Epoch')
plt.ylabel('W-GAP')
plt.title('W-GAP Change over Training Epochs for Upsample-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_2_dtw['epoch'], metrics_history_2_dtw['critic_loss'], label='Critic Loss')
plt.plot(metrics_history_2_dtw['epoch'], metrics_history_2_dtw['gen_loss'], label='Gen Loss')
plt.xlabel('Epoch')
plt.ylabel('Wasserstein Loss')
plt.title('Loss Changes over Training Epochs for Upsample-CNN w/o MVDTW Loss Term')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Transposed 1D Convolution Model W/O MVDTW Loss Term

# %%
model = torch.load("models/UpsampleAndCNN_WGAN/Model_0_GP_10.0_DTW_0.0/Model.pth", weights_only=False)
metrics_history_3_dtw = model['metrics_history']
print(f"MMD: {metrics_history_3_dtw['mmd'][-1]:.4f}")
print(f"MVDTW: {metrics_history_3_dtw['mvdtw'][-1]:.4f}")
print(f"W-Gap: {metrics_history_3_dtw['wgap'][-1]:.4f}")
# Out:
# MMD: 0.0904
# MVDTW: 0.3296
# W-Gap: 0.6029

# %%
plt.plot(metrics_history_3_dtw['epoch'], metrics_history_3_dtw['mmd'])
plt.xlabel('Epoch')
plt.ylabel('MMD')
plt.title('MMD Change over Training Epochs for Transposed-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_3_dtw['epoch'], metrics_history_3_dtw['mvdtw'])
plt.xlabel('Epoch')
plt.ylabel('MVDTW')
plt.title('MVDTW Change over Training Epochs for Transposed-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_3_dtw['epoch'], metrics_history_3_dtw['wgap'])
plt.xlabel('Epoch')
plt.ylabel('W-GAP')
plt.title('W-GAP Change over Training Epochs for Transposed-CNN w/o MVDTW Loss Term')
plt.grid()
plt.show()

# %%
plt.plot(metrics_history_3_dtw['epoch'], metrics_history_3_dtw['critic_loss'], label='Critic Loss')
plt.plot(metrics_history_3_dtw['epoch'], metrics_history_3_dtw['gen_loss'], label='Gen Loss')
plt.xlabel('Epoch')
plt.ylabel('Wasserstein Loss')
plt.title('Loss Changes over Training Epochs for Transposed-CNN w/o MVDTW Loss Term')
plt.grid()
plt.legend()
plt.show()
