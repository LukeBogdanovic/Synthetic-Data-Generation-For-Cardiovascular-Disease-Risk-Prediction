# %% [markdown]
# # PTB XL+ Dataset EDA

# %% [markdown]
# ## Library Imports

# %%
import pandas as pd
import numpy as np
import wfdb
import matplotlib.pyplot as plt
from warnings import filterwarnings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import ast
# ----> 4 import wfdb
#       5 import matplotlib.pyplot as plt
#       6 from warnings import filterwarnings
#
# ModuleNotFoundError: No module named 'wfdb'

# %%
filterwarnings('ignore')

# %%
path = 'C:\\Users\\Luke Bogdanovic\\Downloads\\ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3\\ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3\\'
sampling_rate=100

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv(path+'ptbxl_database.csv')
df.head()
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site     device  \
# 0       1     15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 1       2     13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 2       3     20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 3       4     17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 4       5     17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#         recording_date  ... validated_by_human  baseline_drift static_noise  \
# 0  1984-11-09 09:17:34  ...               True             NaN    , I-V1,
# 1  1984-11-14 12:55:37  ...               True             NaN          NaN
# 2  1984-11-15 12:49:10  ...               True             NaN          NaN
# 3  1984-11-15 13:44:57  ...               True    , II,III,AVF          NaN
# 4  1984-11-17 10:43:15  ...               True   , III,AVR,AVF          NaN
#
#   burst_noise electrodes_problems  extra_beats  pacemaker  strat_fold  \
# 0         NaN                 NaN          NaN        NaN           3
# 1         NaN                 NaN          NaN        NaN           2
# 2         NaN                 NaN          NaN        NaN           5
# 3         NaN                 NaN          NaN        NaN           3
# 4         NaN                 NaN          NaN        NaN           4
#
#                  filename_lr                filename_hr
# 0  records100/00000/00001_lr  records500/00000/00001_hr
# 1  records100/00000/00002_lr  records500/00000/00002_hr
# 2  records100/00000/00003_lr  records500/00000/00003_hr
# 3  records100/00000/00004_lr  records500/00000/00004_hr
# 4  records100/00000/00005_lr  records500/00000/00005_hr
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#        ecg_id  patient_id    age  sex  height  weight  nurse  site  \
# 21794   21833     17180.0   67.0    1     NaN     NaN    1.0   2.0
# 21795   21834     20703.0  300.0    0     NaN     NaN    1.0   2.0
# 21796   21835     19311.0   59.0    1     NaN     NaN    1.0   2.0
# 21797   21836      8873.0   64.0    1     NaN     NaN    1.0   2.0
# 21798   21837     11744.0   68.0    0     NaN     NaN    1.0   2.0
#
#            device       recording_date  ... validated_by_human baseline_drift  \
# 21794  AT-60    3  2001-05-31 09:14:35  ...               True            NaN
# 21795  AT-60    3  2001-06-05 11:33:39  ...               True            NaN
# 21796  AT-60    3  2001-06-08 10:30:27  ...               True            NaN
# 21797  AT-60    3  2001-06-09 18:21:49  ...               True            NaN
# 21798  AT-60    3  2001-06-11 16:43:01  ...               True            NaN
#
#       static_noise burst_noise electrodes_problems  extra_beats  pacemaker  \
# 21794   , alles,           NaN                 NaN          1ES        NaN
# 21795          NaN         NaN                 NaN          NaN        NaN
# 21796   , I-AVR,           NaN                 NaN          NaN        NaN
# 21797          NaN         NaN                 NaN         SVES        NaN
# 21798   , I-AVL,           NaN                 NaN          NaN        NaN
#
#        strat_fold                filename_lr                filename_hr
# 21794           7  records100/21000/21833_lr  records500/21000/21833_hr
# 21795           4  records100/21000/21834_lr  records500/21000/21834_hr
# 21796           2  records100/21000/21835_lr  records500/21000/21835_hr
# 21797           8  records100/21000/21836_lr  records500/21000/21836_hr
# 21798           9  records100/21000/21837_lr  records500/21000/21837_hr
#
# [5 rows x 28 columns]

# %%
df.isna().sum()
# Out:
# ecg_id                              0
# patient_id                          0
# age                                 0
# sex                                 0
# height                          14825
# weight                          12378
# nurse                            1473
# site                               17
# device                              0
# recording_date                      0
# report                              0
# scp_codes                           0
# heart_axis                       8468
# infarction_stadium1             16187
# infarction_stadium2             21696
# validated_by                     9378
# second_opinion                      0
# initial_autogenerated_report        0
# validated_by_human                  0
# baseline_drift                  20201
# static_noise                    18539
# burst_noise                     21186
# electrodes_problems             21769
# extra_beats                     19850
# pacemaker                       21508
# strat_fold                          0
# filename_lr                         0
# filename_hr                         0
# dtype: int64

# %%
df.describe()
# Out:
#              ecg_id    patient_id           age           sex       height  \
# count  21799.000000  21799.000000  21799.000000  21799.000000  6974.000000
# mean   10926.658379  11250.156521     62.769301      0.479150   166.702323
# std     6302.393366   6235.026404     32.308813      0.499577    10.867321
# min        1.000000    302.000000      2.000000      0.000000     6.000000
# 25%     5469.500000   5974.500000     50.000000      0.000000   160.000000
# 50%    10926.000000  11419.000000     62.000000      0.000000   166.000000
# 75%    16386.500000  16607.500000     72.000000      1.000000   174.000000
# max    21837.000000  21797.000000    300.000000      1.000000   209.000000
#
#             weight         nurse          site  validated_by    strat_fold
# count  9421.000000  20326.000000  21782.000000  12421.000000  21799.000000
# mean     70.995223      2.291745      1.544945      0.746075      5.503005
# std      15.878803      3.254033      4.172883      1.178003      2.874948
# min       5.000000      0.000000      0.000000      0.000000      1.000000
# 25%      60.000000      0.000000      0.000000      0.000000      3.000000
# 50%      70.000000      1.000000      1.000000      1.000000      6.000000
# 75%      80.000000      3.000000      2.000000      1.000000      8.000000
# max     250.000000     11.000000     50.000000     11.000000     10.000000

# %%
import tensorflow as tf
from keras import layers, models
from keras.api.datasets import imdb
from keras.api.preprocessing.sequence import pad_sequences
from sklearn.metrics import roc_curve, auc

max_features = 10000
maxlen = 500

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=max_features)

train_data = pad_sequences(train_data, maxlen=maxlen)
test_data = pad_sequences(test_data, maxlen=maxlen)

model = models.Sequential([
    layers.Embedding(max_features, 128, input_length=maxlen),
    layers.Conv1D(32, 7, activation='relu'),
    layers.MaxPooling1D(5),
    layers.Conv1D(32, 7, activation='relu'),
    layers.GlobalMaxPooling1D(),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

model.fit(train_data, train_labels, epochs=5, batch_size=64, validation_split=0.2)

test_loss, test_acc, test_auc = model.evaluate(test_data, test_labels)
print(f'Test accuracy: {test_acc:.2f}')
print(f'Test AUC: {test_auc:.2f}')

model.save("imdb_cnn_model.h5")

predictions = model.predict(test_data).ravel()
fpr, tpr, thresholds = roc_curve(test_labels, predictions)
roc_auc = auc(fpr, tpr)
print(f'Sklearn AUC: {roc_auc:.2f}')
# Out:
# 2024-10-23 16:24:58.174609: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-23 16:24:58.201186: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-23 16:24:58.207671: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-23 16:24:58.228637: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-23 16:24:59.082519: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/elukbog/.local/lib/python3.10/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729697103.157343   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729697103.304982   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729697103.305046   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729697103.306616   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729697103.306664   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729697103.306696   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:0
# Epoch 1/5
# 0:1729697103.413369   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1729697103.413550   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-23 16:25:03.413564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1729697103.413726   13503 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-23 16:25:03.413863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9122 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti, pci bus id: 0000:09:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729697120.399529    1893 service.cc:146] XLA service 0x7f890c0025f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729697120.399948    1893 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti, Compute Capability 8.9
# 2024-10-23 16:25:20.476473: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-23 16:25:20.724620: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#  76/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4994 - auc: 0.5182 - loss: 0.6926
# I0000 00:00:1729697122.459700    1893 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6353 - auc: 0.7068 - loss: 0.5889 - val_accuracy: 0.8580 - val_auc: 0.9429 - val_loss: 0.3312
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9102 - auc: 0.9684 - loss: 0.2282 - val_accuracy: 0.8748 - val_auc: 0.9500 - val_loss: 0.2986
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9637 - auc: 0.9930 - loss: 0.1103 - val_accuracy: 0.8772 - val_auc: 0.9463 - val_loss: 0.3535
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9883 - auc: 0.9987 - loss: 0.0472 - val_accuracy: 0.8704 - val_auc: 0.9379 - val_loss: 0.4595
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9985 - auc: 0.9997 - loss: 0.0134 - val_accuracy: 0.8744 - val_auc: 0.9317 - val_loss: 0.5550
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8572 - auc: 0.9211 - loss: 0.6032
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.86
# Test AUC: 0.92
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Sklearn AUC: 0.93

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

predictions_binary = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predictions_binary)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Positive', 'Negative'], yticklabels=['Positive', 'Negative'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix For IMDB')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 500, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 494, 32)        │        28,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 98, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 92, 32)         │         7,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 32)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,947,813 (15.06 MB)
#  Trainable params: 1,315,937 (5.02 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,631,876 (10.04 MB)

# %%
from keras.api.utils import plot_model
plot_model(model)

# %%
import wfdb

record = wfdb.rdrecord("dataset/01911",sampfrom=20000,sampto=20250)
wfdb.plot_wfdb(record=record, title="Shareedb signal 01911")

# %%
record2 = wfdb.rdrecord("dataset/02012", sampfrom=20000, sampto=20250)
wfdb.plot_wfdb(record=record2, title="Shareedb signal 02012")
